# %%
import pandas as pd
from tabulate import tabulate

# %% [markdown]
# ## Overview

# %%
A_file = 'dataset.csv'
data = pd.read_csv(A_file)
print(data.shape)
# Out:
# (55948, 88)

# %%
TARGET = 'maxmora'
split_binary = 3

# %%
data = data.groupby(TARGET)[[TARGET]].count().reset_index(drop=True)
data['maxmora_pct'] = round(data['maxmora'] / data['maxmora'].sum() * 100, 2)
data_groups = data.copy()
labels = ["{0} - {1}".format(data.index.min(), split_binary - 1), 
          "{0} - {1}".format(split_binary, data.index.max())
         ]
data_groups['groups'] = pd.cut(data.index, 
                               [data.index.min(), split_binary, data.index.max()+1], 
                               right=False, 
                               labels = labels
                              )
data_groups = data_groups.groupby('groups').sum()
data_groups.index.name = None
#print(f'Dataset Target Distribution')
#print(data, '\n', data_groups)
print(f"dataset distribution:\n{tabulate(data, headers='keys', tablefmt='psql')}")
print(f"dataset distribution by group:\n{tabulate(data_groups, headers='keys', tablefmt='psql')}")
# Out:
# dataset distribution:
# +----+-----------+---------------+
# |    |   maxmora |   maxmora_pct |
# |----+-----------+---------------|
# |  0 |     16697 |         29.84 |
# |  1 |     26533 |         47.42 |
# |  2 |      4158 |          7.43 |
# |  3 |      2077 |          3.71 |
# |  4 |      5660 |         10.12 |
# |  5 |       658 |          1.18 |
# |  6 |       165 |          0.29 |
# +----+-----------+---------------+
# dataset distribution by group:
# +-------+-----------+---------------+
# |       |   maxmora |   maxmora_pct |
# |-------+-----------+---------------|
# | 0 - 2 |     47388 |         84.69 |
# | 3 - 6 |      8560 |         15.3  |
# +-------+-----------+---------------+

# %% [markdown]
# ## Compare two datasets

# %%
A_file = 'dataset.csv'
B_file = 'dataset20210312.csv'

# %%
A = pd.read_csv(A_file)
B = pd.read_csv(B_file)

# %%
print(A.shape, B.shape)
# Out:
# (53395, 88) (67887, 88)

# %%
aset = set(A['id_solicitud'])
bset = set(B['id_solicitud'])

# %%
print('Registers that are in A but not in B:', len(bset - aset))
# Out:
# Registers that are in A but not in B: 0

# %%
print('Registers that are in A but not in B:', len(aset - bset))
# Out:
# Registers that are in A but not in B: 496

# %%
print('Dplicated in A', A[A.duplicated()].shape[0], 'Duplicated in B', B[B.duplicated()].shape[0])
# Out:
# Dplicated in A 0 Duplicated in B 14988

# %%
B[B.duplicated(keep=False)].sort_values(by=['id_solicitud'])
# Out:
#          id_solicitud fecha_desembolso  monto_dsale  maxmora  id_tramite  \
# 26510      GT-1017430       2020-08-22      10000.0        1  GT-1017430
# 26511      GT-1017430       2020-08-22      10000.0        1  GT-1017430
# 29872  GT-01036542300021  ...                                    Si
# 41191  GT-01032037500031  ...                                    Si
# ...                  ...  ...                                   ...
# 10241  GT-01024406400042  ...                                   NaN
# 535    GT-01015752400048  ...                                   NaN
# 536    GT-01015752400048  ...                                   NaN
# 6975   GT-01014457300010  ...                                   NaN
# 6974   GT-01014457300010  ...                                   NaN
#
#        cl_unq_act_act_flagtienelavadora  cl_unq_act_act_flagtienesecadora  \
# 26510                                No                                No
# 26511                                No                                No
# 29873                                No                                No
# 29872                                No                                No
# 41191                                No                                No
# ...                                 ...                               ...
# 10241                               NaN                               NaN
# 535                                 NaN                               NaN
# 536                                 NaN                               NaN
# 6975                                NaN                               NaN
# 6974                                NaN                               NaN
#
#        cl_unq_act_act_flagtienehorno  cl_unq_act_act_flagtienemicroondas  \
# 26510                             Si                                  Si
# 26511                             Si                                  Si
# 29873                             Si                                  No
# 29872                             Si                                  No
# 41191                             Si                                  No
# ...                              ...                                 ...
# 10241                            NaN                                 NaN
# 535                              NaN                                 NaN
# 536                              NaN                                 NaN
# 6975                             NaN                                 NaN
# 6974                             NaN                                 NaN
#
#        cl_unq_act_act_flagtienestereo cl_unq_act_act_fnacimiento_date  \
# 26510                              Si             1987-08-25 00:00:00
# 26511                              Si             1987-08-25 00:00:00
# 29873                              Si             1980-12-12 00:00:00
# 29872                              Si             1980-12-12 00:00:00
# 41191                              No             1994-12-14 00:00:00
# ...                               ...                             ...
# 10241                             NaN                             NaN
# 535                               NaN                             NaN
# 536                               NaN                             NaN
# 6975                              NaN                             NaN
# 6974                              NaN                             NaN
#
#        cl_unq_act_act_finicionegocio_date  \
# 26510                 2010-11-08 00:00:00
# 26511                 2010-11-08 00:00:00
# 29873                 2014-03-07 00:00:00
# 29872                 2014-03-07 00:00:00
# 41191                 2015-02-11 00:00:00
# ...                                   ...
# 10241                                 NaN
# 535                                   NaN
# 536                                   NaN
# 6975                                  NaN
# 6974                                  NaN
#
#       cl_unq_act_act_fnacimiento_date_numberlong  \
# 26510                                        NaN
# 26511                                        NaN
# 29873                                        NaN
# 29872                                        NaN
# 41191                                        NaN
# ...                                          ...
# 10241                                        NaN
# 535                                          NaN
# 536                                          NaN
# 6975                                         NaN
# 6974                                         NaN
#
#       cl_unq_act_act_finicionegocio_date_numberlong
# 26510                                           NaN
# 26511                                           NaN
# 29873                                           NaN
# 29872                                           NaN
# 41191                                           NaN
# ...                                             ...
# 10241                                           NaN
# 535                                             NaN
# 536                                             NaN
# 6975                                            NaN
# 6974                                            NaN
#
# [29976 rows x 88 columns]
